# %%
import keras_nlp
from tensorflow import tensorflow_datasets as tfds

imdb_train, imdb_test = tfds.load(
    "imdb_reviews",
    split=["train", "test"],
    as_supervised=True,
    batch_size=16,
)
# Load a BERT model.
classifier = keras_nlp.models.BertClassifier.from_preset(
    "bert_base_en_uncased", 
    num_classes=2,
    activation="softmax",
)
# Fine-tune on IMDb movie reviews.
classifier.fit(imdb_train, validation_data=imdb_test)
# Predict two new examples.
classifier.predict(["What an amazing movie!", "A total waste of my time."])
# Out:
# Using JAX backend.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\jgalb\Desktop\College\Code\verza\src\chatbot\modelcode.ipynb Cell 1 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/jgalb/Desktop/College/Code/verza/src/chatbot/modelcode.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import os
#       <a href='vscode-notebook-cell:/c%3A/Users/jgalb/Desktop/College/Code/verza/src/chatbot/modelcode.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> os.environ["KERAS_BACKEND"] = "jax"  # Or "tensorflow", or "torch".
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jgalb/Desktop/College/Code/verza/src/chatbot/modelcode.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> import keras_nlp
#       <a href='vscode-notebook-cell:/c%3A/Users/jgalb/Desktop/College/Code/verza/src/chatbot/modelcode.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> from tensorflow import tensorflow_datasets as tfds
#       <a href='vscode-notebook-cell:/c%3A/Users/jgalb/Desktop/College/Code/verza/src/chatbot/modelcode.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> imdb_train, imdb_test = tfds.load(
#       <a href='vscode-notebook-cell:/c%3A/Users/jgalb/Desktop/College/Code/verza/src/chatbot/modelcode.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a>     "imdb_reviews",
#       <a href='vscode-notebook-cell:/c%3A/Users/jgalb/Desktop/College/Code/verza/src/chatbot/modelcode.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a>     split=["train", "test"],
#      <a href='vscode-notebook-cell:/c%3A/Users/jgalb/Desktop/College/Code/verza/src/chatbot/modelcode.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a>     as_supervised=True,
#      <a href='vscode-notebook-cell:/c%3A/Users/jgalb/Desktop/College/Code/verza/src/chatbot/modelcode.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a>     batch_size=16,
#      <a href='vscode-notebook-cell:/c%3A/Users/jgalb/Desktop/College/Code/verza/src/chatbot/modelcode.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a> )
#
# File c:\Users\jgalb\anaconda3\envs\verza\lib\site-packages\keras_nlp\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras_nlp import layers
#       9 from keras_nlp import metrics
#      10 from keras_nlp import models
#
# File c:\Users\jgalb\anaconda3\envs\verza\lib\site-packages\keras_nlp\layers\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras_nlp.src.layers.modeling.cached_multi_head_attention import CachedMultiHeadAttention
#       9 from keras_nlp.src.layers.modeling.f_net_encoder import FNetEncoder
#      10 from keras_nlp.src.layers.modeling.masked_lm_head import MaskedLMHead
#
# File c:\Users\jgalb\anaconda3\envs\verza\lib\site-packages\keras_nlp\src\__init__.py:23
#      20 except ImportError:
#      21     pass
# ---> 23 from keras_nlp.src import layers
#      24 from keras_nlp.src import metrics
#      25 from keras_nlp.src import models
#
# File c:\Users\jgalb\anaconda3\envs\verza\lib\site-packages\keras_nlp\src\layers\__init__.py:15
#       1 # Copyright 2023 The KerasNLP Authors
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 15 from keras_nlp.src.layers.modeling.cached_multi_head_attention import (
#      16     CachedMultiHeadAttention,
#      17 )
#      18 from keras_nlp.src.layers.modeling.f_net_encoder import FNetEncoder
#      19 from keras_nlp.src.layers.modeling.masked_lm_head import MaskedLMHead
#
# File c:\Users\jgalb\anaconda3\envs\verza\lib\site-packages\keras_nlp\src\layers\modeling\cached_multi_head_attention.py:15
#       1 # Copyright 2023 The KerasNLP Authors
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 15 from keras_nlp.src.api_export import keras_nlp_export
#      16 from keras_nlp.src.backend import keras
#      17 from keras_nlp.src.backend import ops
#
# File c:\Users\jgalb\anaconda3\envs\verza\lib\site-packages\keras_nlp\src\api_export.py:17
#       1 # Copyright 2023 The KerasNLP Authors
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 import types
# ---> 17 from keras_nlp.src.backend import keras
#      19 try:
#      20     import namex
#
# File c:\Users\jgalb\anaconda3\envs\verza\lib\site-packages\keras_nlp\src\backend\__init__.py:27
#       1 # Copyright 2023 The KerasNLP Authors
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      14 """
#      15 Keras backend module.
#      16
#    (...)
#      24 - `random`: `keras_core.random`, always tf backed if using `tf.keras`.
#      25 """
# ---> 27 from keras_nlp.src.backend import config
#      28 from keras_nlp.src.backend import keras
#      29 from keras_nlp.src.backend import ops
#
# File c:\Users\jgalb\anaconda3\envs\verza\lib\site-packages\keras_nlp\src\backend\config.py:18
#      15 import json
#      16 import os
# ---> 18 import keras_core
#      20 _MULTI_BACKEND = False
#      22 # Set Keras base dir path given KERAS_HOME env variable, if applicable.
#      23 # Otherwise either ~/.keras or /tmp.
#
# File c:\Users\jgalb\anaconda3\envs\verza\lib\site-packages\keras_core\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras_core import _tf_keras
#       9 from keras_core import activations
#      10 from keras_core import applications
#
# File c:\Users\jgalb\anaconda3\envs\verza\lib\site-packages\keras_core\_tf_keras\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras_core import activations
#       9 from keras_core import applications
#      10 from keras_core import callbacks
#
# File c:\Users\jgalb\anaconda3\envs\verza\lib\site-packages\keras_core\activations\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras_core.src.activations import deserialize
#       9 from keras_core.src.activations import get
#      10 from keras_core.src.activations import serialize
#
# File c:\Users\jgalb\anaconda3\envs\verza\lib\site-packages\keras_core\src\__init__.py:1
# ----> 1 from keras_core.src import activations
#       2 from keras_core.src import applications
#       3 from keras_core.src import backend
#
# File c:\Users\jgalb\anaconda3\envs\verza\lib\site-packages\keras_core\src\activations\__init__.py:3
#       1 import types
# ----> 3 from keras_core.src.activations.activations import elu
#       4 from keras_core.src.activations.activations import exponential
#       5 from keras_core.src.activations.activations import gelu
#
# File c:\Users\jgalb\anaconda3\envs\verza\lib\site-packages\keras_core\src\activations\activations.py:1
# ----> 1 from keras_core.src import backend
#       2 from keras_core.src import ops
#       3 from keras_core.src.api_export import keras_core_export
#
# File c:\Users\jgalb\anaconda3\envs\verza\lib\site-packages\keras_core\src\backend\__init__.py:39
#      37 elif backend() == "jax":
#      38     print_msg("Using JAX backend.")
# ---> 39     from keras_core.src.backend.jax import *  # noqa: F403
#      40 elif backend() == "torch":
#      41     print_msg("Using PyTorch backend.")
#
# File c:\Users\jgalb\anaconda3\envs\verza\lib\site-packages\keras_core\src\backend\jax\__init__.py:1
# ----> 1 from keras_core.src.backend.jax import core
#       2 from keras_core.src.backend.jax import distribution_lib
#       3 from keras_core.src.backend.jax import image
#
# File c:\Users\jgalb\anaconda3\envs\verza\lib\site-packages\keras_core\src\backend\jax\core.py:3
#       1 import types
# ----> 3 import jax
#       4 import jax.numpy as jnp
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'jax'
